# %%
import numpy as np

# %% [markdown]
# Running the model requires pybamm to be installed on the "degradation" branch. The results are plotted in `figure_electrode_saturation_pybamm.py`.

# %% [markdown]
# ## Solve the model

# %%
import pybamm

def lico2_volume_change_Ai2020(sto):
    omega = pybamm.Parameter("Positive electrode partial molar volume [m3.mol-1]")
    c_p_max = pybamm.Parameter("Maximum concentration in positive electrode [mol.m-3]")
    t_change = omega * c_p_max * sto
    return t_change

def graphite_volume_change_Ai2020(sto):
    p1 = 145.907
    p2 = -681.229
    p3 = 1334.442
    p4 = -1415.710
    p5 = 873.906
    p6 = -312.528
    p7 = 60.641
    p8 = -5.706
    p9 = 0.386
    p10 = -4.966e-05
    t_change = (
        p1 * sto ** 9
        + p2 * sto ** 8
        + p3 * sto ** 7
        + p4 * sto ** 6
        + p5 * sto ** 5
        + p6 * sto ** 4
        + p7 * sto ** 3
        + p8 * sto ** 2
        + p9 * sto
        + p10
    )
    return t_change

def get_parameter_values():
    parameter_values = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Mohtat2020)
    parameter_values.update(
        {
            # mechanical properties
            "Positive electrode Poisson's ratio": 0.3,
            "Positive electrode Young's modulus [Pa]": 375e9,
            "Positive electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Positive electrode partial molar volume [m3.mol-1]": -7.28e-7,
            "Positive electrode volume change": lico2_volume_change_Ai2020,
            # Loss of active materials (LAM) model
            "Positive electrode LAM constant exponential term": 2,
            "Positive electrode critical stress [Pa]": 375e6,
            # mechanical properties
            "Negative electrode Poisson's ratio": 0.2,
            "Negative electrode Young's modulus [Pa]": 15e9,
            "Negative electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Negative electrode partial molar volume [m3.mol-1]": 3.1e-6,
            "Negative electrode volume change": graphite_volume_change_Ai2020,
            # Loss of active materials (LAM) model
            "Negative electrode LAM constant exponential term": 2,
            "Negative electrode critical stress [Pa]": 60e6,
            # Other
            "Cell thermal expansion coefficient [m.K-1]": 1.48E-6,
        },
        check_already_exists=False,
    )
    return parameter_values

parameter_values = get_parameter_values()
parameter_values.update(
    {
        "SEI kinetic rate constant [m.s-1]": 1e-15,
        "Positive electrode LAM constant propotional term": 1e-3,
        "Negative electrode LAM constant propotional term": 1e-3,
        "EC diffusivity [m2.s-1]": 2e-18,
    },
    check_already_exists=False,
)
spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        "loss of active material": "stress-driven",
    }
)

# %%
esoh_model = pybamm.lithium_ion.ElectrodeSOH()
esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
param = spm.param

Vmin = 3.0
Vmax = 4.2
Cn = parameter_values.evaluate(param.C_n_init)
Cp = parameter_values.evaluate(param.C_p_init)
n_Li_init = parameter_values.evaluate(param.n_Li_particles_init)
c_n_max = parameter_values.evaluate(param.c_n_max)
c_p_max = parameter_values.evaluate(param.c_p_max)

esoh_sol = esoh_sim.solve(
    [0],
    inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
)
print(esoh_sol["x_100"].data[0])
print(esoh_sol["y_100"].data[0])
# Out:
# 0.8333742762029194
# 0.0335455473745956

# %%
eps_n = parameter_values["Negative electrode active material volume fraction"]
eps_p = parameter_values["Positive electrode active material volume fraction"]
C_over_eps_n = Cn / eps_n
C_over_eps_p = Cp / eps_p

# %%
pybamm.set_logging_level("NOTICE")
experiment = pybamm.Experiment(
    [
        ("Discharge at 1C until 3V",
         "Rest for 1 hour",
         "Charge at 1C until 4.2V", 
         "Hold at 4.2V until C/50")
    ] * 1200,
    termination="60% capacity",
#     cccv_handling="ode",
)

# %% [markdown]
# Parameter values that give a knee point

# %%
parameter_values_knee = get_parameter_values()
parameter_values_knee.update(
    {
        "SEI kinetic rate constant [m.s-1]": 1e-17,
        "Positive electrode LAM constant propotional term": 7e-3,
        "Negative electrode LAM constant propotional term": 7e-3,
        "EC diffusivity [m2.s-1]": 2e-18,
    },
    check_already_exists=False,
)

# %%
sim_long_knee = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values_knee, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_knee = sim_long_knee.solve(initial_soc=1)
# Out:
# 2021-08-20 16:51:01,354 - [NOTICE] simulation.solve(784): Cycle 1/1200 (36.252 ms elapsed) --------------------
# 2021-08-20 16:51:01,355 - [NOTICE] simulation.solve(818): Cycle 1/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:01,466 - [NOTICE] simulation.solve(818): Cycle 1/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:01,521 - [NOTICE] simulation.solve(818): Cycle 1/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:01,606 - [NOTICE] simulation.solve(818): Cycle 1/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:01,897 - [NOTICE] simulation.solve(896): Capacity is now 4.968 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:01,897 - [NOTICE] simulation.solve(784): Cycle 2/1200 (579.417 ms elapsed) --------------------
# 2021-08-20 16:51:01,898 - [NOTICE] simulation.solve(818): Cycle 2/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:01,936 - [NOTICE] simulation.solve(818): Cycle 2/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:01,965 - [NOTICE] simulation.solve(818): Cycle 2/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:02,001 - [NOTICE] simulation.solve(818): Cycle 2/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:02,049 - [NOTICE] simulation.solve(896): Capacity is now 4.967 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:02,050 - [NOTICE] simulation.solve(784): Cycle 3/1200 (732.003 ms elapsed) --------------------
# 2021-08-20 16:51:02,050 - [NOTICE] simulation.solve(818): Cycle 3/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:02,096 - [NOTICE] simulation.solve(818): Cycle 3/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:02,128 - [NOTICE] simulation.solve(818): Cycle 3/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:02,166 - [NOTICE] simulation.solve(818): Cycle 3/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:02,222 - [NOTICE] simulation.solve(896): Capacity is now 4.966 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:02,223 - [NOTICE] simulation.solve(784): Cycle 4/1200 (905.122 ms elapsed) --------------------
# 2021-08-20 16:51:02,223 - [NOTICE] simulation.solve(818): Cycle 4/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:02,265 - [NOTICE] simulation.solve(818): Cycle 4/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:02,292 - [NOTICE] simulation.solve(818): Cycle 4/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:02,328 - [NOTICE] simulation.solve(818): Cycle 4/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:02,378 - [NOTICE] simulation.solve(896): Capacity is now 4.965 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:02,378 - [NOTICE] simulation.solve(784): Cycle 5/1200 (1.060 s elapsed) --------------------
# 2021-08-20 16:51:02,379 - [NOTICE] simulation.solve(818): Cycle 5/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:02,420 - [NOTICE] simulation.solve(818): Cycle 5/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:02,448 - [NOTICE] simulation.solve(818): Cycle 5/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:02,483 - [NOTICE] simulation.solve(818): Cycle 5/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:02,541 - [NOTICE] simulation.solve(896): Capacity is now 4.964 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:02,542 - [NOTICE] simulation.solve(784): Cycle 6/1200 (1.224 s elapsed) --------------------
# 2021-08-20 16:51:02,543 - [NOTICE] simulation.solve(818): Cycle 6/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:02,594 - [NOTICE] simulation.solve(818): Cycle 6/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:02,631 - [NOTICE] simulation.solve(818): Cycle 6/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:02,682 - [NOTICE] simulation.solve(818): Cycle 6/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:02,768 - [NOTICE] simulation.solve(896): Capacity is now 4.963 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:02,769 - [NOTICE] simulation.solve(784): Cycle 7/1200 (1.451 s elapsed) --------------------
# 2021-08-20 16:51:02,769 - [NOTICE] simulation.solve(818): Cycle 7/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:02,834 - [NOTICE] simulation.solve(818): Cycle 7/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:02,870 - [NOTICE] simulation.solve(818): Cycle 7/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:02,916 - [NOTICE] simulation.solve(818): Cycle 7/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:03,056 - [NOTICE] simulation.solve(896): Capacity is now 4.962 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:03,064 - [NOTICE] simulation.solve(784): Cycle 8/1200 (1.746 s elapsed) --------------------
# 2021-08-20 16:51:03,065 - [NOTICE] simulation.solve(818): Cycle 8/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:03,291 - [NOTICE] simulation.solve(818): Cycle 8/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:03,342 - [NOTICE] simulation.solve(818): Cycle 8/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:03,385 - [NOTICE] simulation.solve(818): Cycle 8/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:03,433 - [NOTICE] simulation.solve(896): Capacity is now 4.961 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:03,433 - [NOTICE] simulation.solve(784): Cycle 9/1200 (2.116 s elapsed) --------------------
# 2021-08-20 16:51:03,434 - [NOTICE] simulation.solve(818): Cycle 9/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:03,470 - [NOTICE] simulation.solve(818): Cycle 9/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:03,501 - [NOTICE] simulation.solve(818): Cycle 9/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:03,543 - [NOTICE] simulation.solve(818): Cycle 9/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:03,597 - [NOTICE] simulation.solve(896): Capacity is now 4.960 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:03,597 - [NOTICE] simulation.solve(784): Cycle 10/1200 (2.280 s elapsed) --------------------
# 2021-08-20 16:51:03,598 - [NOTICE] simulation.solve(818): Cycle 10/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:03,638 - [NOTICE] simulation.solve(818): Cycle 10/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:03,673 - [NOTICE] simulation.solve(818): Cycle 10/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:03,728 - [NOTICE] simulation.solve(818): Cycle 10/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:03,806 - [NOTICE] simulation.solve(896): Capacity is now 4.959 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:03,807 - [NOTICE] simulation.solve(784): Cycle 11/1200 (2.489 s elapsed) --------------------
# 2021-08-20 16:51:03,807 - [NOTICE] simulation.solve(818): Cycle 11/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:03,849 - [NOTICE] simulation.solve(818): Cycle 11/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:03,881 - [NOTICE] simulation.solve(818): Cycle 11/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:03,918 - [NOTICE] simulation.solve(818): Cycle 11/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:03,977 - [NOTICE] simulation.solve(896): Capacity is now 4.959 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:03,978 - [NOTICE] simulation.solve(784): Cycle 12/1200 (2.660 s elapsed) --------------------
# 2021-08-20 16:51:03,978 - [NOTICE] simulation.solve(818): Cycle 12/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,022 - [NOTICE] simulation.solve(818): Cycle 12/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,055 - [NOTICE] simulation.solve(818): Cycle 12/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:04,091 - [NOTICE] simulation.solve(818): Cycle 12/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:04,142 - [NOTICE] simulation.solve(896): Capacity is now 4.958 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:04,143 - [NOTICE] simulation.solve(784): Cycle 13/1200 (2.825 s elapsed) --------------------
# 2021-08-20 16:51:04,143 - [NOTICE] simulation.solve(818): Cycle 13/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,187 - [NOTICE] simulation.solve(818): Cycle 13/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,215 - [NOTICE] simulation.solve(818): Cycle 13/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:04,255 - [NOTICE] simulation.solve(818): Cycle 13/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:04,312 - [NOTICE] simulation.solve(896): Capacity is now 4.957 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:04,313 - [NOTICE] simulation.solve(784): Cycle 14/1200 (2.995 s elapsed) --------------------
# 2021-08-20 16:51:04,313 - [NOTICE] simulation.solve(818): Cycle 14/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,357 - [NOTICE] simulation.solve(818): Cycle 14/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,386 - [NOTICE] simulation.solve(818): Cycle 14/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:04,424 - [NOTICE] simulation.solve(818): Cycle 14/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:04,477 - [NOTICE] simulation.solve(896): Capacity is now 4.956 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:04,477 - [NOTICE] simulation.solve(784): Cycle 15/1200 (3.159 s elapsed) --------------------
# 2021-08-20 16:51:04,478 - [NOTICE] simulation.solve(818): Cycle 15/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,518 - [NOTICE] simulation.solve(818): Cycle 15/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,544 - [NOTICE] simulation.solve(818): Cycle 15/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:04,581 - [NOTICE] simulation.solve(818): Cycle 15/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:04,637 - [NOTICE] simulation.solve(896): Capacity is now 4.955 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:04,637 - [NOTICE] simulation.solve(784): Cycle 16/1200 (3.320 s elapsed) --------------------
# 2021-08-20 16:51:04,638 - [NOTICE] simulation.solve(818): Cycle 16/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,681 - [NOTICE] simulation.solve(818): Cycle 16/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,707 - [NOTICE] simulation.solve(818): Cycle 16/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:04,740 - [NOTICE] simulation.solve(818): Cycle 16/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:04,787 - [NOTICE] simulation.solve(896): Capacity is now 4.954 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:04,787 - [NOTICE] simulation.solve(784): Cycle 17/1200 (3.469 s elapsed) --------------------
# 2021-08-20 16:51:04,787 - [NOTICE] simulation.solve(818): Cycle 17/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,824 - [NOTICE] simulation.solve(818): Cycle 17/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,849 - [NOTICE] simulation.solve(818): Cycle 17/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:04,882 - [NOTICE] simulation.solve(818): Cycle 17/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:04,926 - [NOTICE] simulation.solve(896): Capacity is now 4.953 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:04,927 - [NOTICE] simulation.solve(784): Cycle 18/1200 (3.609 s elapsed) --------------------
# 2021-08-20 16:51:04,927 - [NOTICE] simulation.solve(818): Cycle 18/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:04,961 - [NOTICE] simulation.solve(818): Cycle 18/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:04,986 - [NOTICE] simulation.solve(818): Cycle 18/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:05,020 - [NOTICE] simulation.solve(818): Cycle 18/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:05,063 - [NOTICE] simulation.solve(896): Capacity is now 4.952 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:05,064 - [NOTICE] simulation.solve(784): Cycle 19/1200 (3.746 s elapsed) --------------------
# 2021-08-20 16:51:05,064 - [NOTICE] simulation.solve(818): Cycle 19/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:05,102 - [NOTICE] simulation.solve(818): Cycle 19/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:05,130 - [NOTICE] simulation.solve(818): Cycle 19/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:05,166 - [NOTICE] simulation.solve(818): Cycle 19/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:05,217 - [NOTICE] simulation.solve(896): Capacity is now 4.951 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:05,218 - [NOTICE] simulation.solve(784): Cycle 20/1200 (3.900 s elapsed) --------------------
# 2021-08-20 16:51:05,218 - [NOTICE] simulation.solve(818): Cycle 20/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:05,258 - [NOTICE] simulation.solve(818): Cycle 20/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:05,300 - [NOTICE] simulation.solve(818): Cycle 20/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:05,342 - [NOTICE] simulation.solve(818): Cycle 20/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:05,406 - [NOTICE] simulation.solve(896): Capacity is now 4.950 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:05,406 - [NOTICE] simulation.solve(784): Cycle 21/1200 (4.088 s elapsed) --------------------
# 2021-08-20 16:51:05,407 - [NOTICE] simulation.solve(818): Cycle 21/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:05,451 - [NOTICE] simulation.solve(818): Cycle 21/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:05,479 - [NOTICE] simulation.solve(818): Cycle 21/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:05,518 - [NOTICE] simulation.solve(818): Cycle 21/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:05,576 - [NOTICE] simulation.solve(896): Capacity is now 4.949 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:05,577 - [NOTICE] simulation.solve(784): Cycle 22/1200 (4.259 s elapsed) --------------------
# 2021-08-20 16:51:05,577 - [NOTICE] simulation.solve(818): Cycle 22/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:05,634 - [NOTICE] simulation.solve(818): Cycle 22/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:05,897 - [NOTICE] simulation.solve(818): Cycle 22/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:05,958 - [NOTICE] simulation.solve(818): Cycle 22/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,004 - [NOTICE] simulation.solve(896): Capacity is now 4.948 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,005 - [NOTICE] simulation.solve(784): Cycle 23/1200 (4.687 s elapsed) --------------------
# 2021-08-20 16:51:06,005 - [NOTICE] simulation.solve(818): Cycle 23/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,041 - [NOTICE] simulation.solve(818): Cycle 23/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,066 - [NOTICE] simulation.solve(818): Cycle 23/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:06,098 - [NOTICE] simulation.solve(818): Cycle 23/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,146 - [NOTICE] simulation.solve(896): Capacity is now 4.947 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,146 - [NOTICE] simulation.solve(784): Cycle 24/1200 (4.829 s elapsed) --------------------
# 2021-08-20 16:51:06,147 - [NOTICE] simulation.solve(818): Cycle 24/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,185 - [NOTICE] simulation.solve(818): Cycle 24/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,212 - [NOTICE] simulation.solve(818): Cycle 24/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:06,248 - [NOTICE] simulation.solve(818): Cycle 24/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,297 - [NOTICE] simulation.solve(896): Capacity is now 4.946 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,298 - [NOTICE] simulation.solve(784): Cycle 25/1200 (4.980 s elapsed) --------------------
# 2021-08-20 16:51:06,298 - [NOTICE] simulation.solve(818): Cycle 25/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,341 - [NOTICE] simulation.solve(818): Cycle 25/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,370 - [NOTICE] simulation.solve(818): Cycle 25/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:06,408 - [NOTICE] simulation.solve(818): Cycle 25/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,452 - [NOTICE] simulation.solve(896): Capacity is now 4.945 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,452 - [NOTICE] simulation.solve(784): Cycle 26/1200 (5.135 s elapsed) --------------------
# 2021-08-20 16:51:06,453 - [NOTICE] simulation.solve(818): Cycle 26/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,487 - [NOTICE] simulation.solve(818): Cycle 26/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,511 - [NOTICE] simulation.solve(818): Cycle 26/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:06,543 - [NOTICE] simulation.solve(818): Cycle 26/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,586 - [NOTICE] simulation.solve(896): Capacity is now 4.944 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,587 - [NOTICE] simulation.solve(784): Cycle 27/1200 (5.269 s elapsed) --------------------
# 2021-08-20 16:51:06,587 - [NOTICE] simulation.solve(818): Cycle 27/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,621 - [NOTICE] simulation.solve(818): Cycle 27/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,646 - [NOTICE] simulation.solve(818): Cycle 27/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:06,678 - [NOTICE] simulation.solve(818): Cycle 27/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,729 - [NOTICE] simulation.solve(896): Capacity is now 4.943 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,729 - [NOTICE] simulation.solve(784): Cycle 28/1200 (5.411 s elapsed) --------------------
# 2021-08-20 16:51:06,729 - [NOTICE] simulation.solve(818): Cycle 28/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,770 - [NOTICE] simulation.solve(818): Cycle 28/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,796 - [NOTICE] simulation.solve(818): Cycle 28/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:06,831 - [NOTICE] simulation.solve(818): Cycle 28/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:06,894 - [NOTICE] simulation.solve(896): Capacity is now 4.942 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:06,895 - [NOTICE] simulation.solve(784): Cycle 29/1200 (5.577 s elapsed) --------------------
# 2021-08-20 16:51:06,896 - [NOTICE] simulation.solve(818): Cycle 29/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:06,944 - [NOTICE] simulation.solve(818): Cycle 29/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:06,976 - [NOTICE] simulation.solve(818): Cycle 29/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:07,018 - [NOTICE] simulation.solve(818): Cycle 29/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:07,094 - [NOTICE] simulation.solve(896): Capacity is now 4.941 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:07,095 - [NOTICE] simulation.solve(784): Cycle 30/1200 (5.777 s elapsed) --------------------
# 2021-08-20 16:51:07,096 - [NOTICE] simulation.solve(818): Cycle 30/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:07,172 - [NOTICE] simulation.solve(818): Cycle 30/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:07,239 - [NOTICE] simulation.solve(818): Cycle 30/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:07,330 - [NOTICE] simulation.solve(818): Cycle 30/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:07,441 - [NOTICE] simulation.solve(896): Capacity is now 4.940 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:07,442 - [NOTICE] simulation.solve(784): Cycle 31/1200 (6.124 s elapsed) --------------------
# 2021-08-20 16:51:07,443 - [NOTICE] simulation.solve(818): Cycle 31/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:07,493 - [NOTICE] simulation.solve(818): Cycle 31/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:07,524 - [NOTICE] simulation.solve(818): Cycle 31/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:07,561 - [NOTICE] simulation.solve(818): Cycle 31/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:07,619 - [NOTICE] simulation.solve(896): Capacity is now 4.940 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:07,620 - [NOTICE] simulation.solve(784): Cycle 32/1200 (6.302 s elapsed) --------------------
# 2021-08-20 16:51:07,620 - [NOTICE] simulation.solve(818): Cycle 32/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:07,859 - [NOTICE] simulation.solve(818): Cycle 32/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:07,891 - [NOTICE] simulation.solve(818): Cycle 32/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:07,939 - [NOTICE] simulation.solve(818): Cycle 32/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:07,987 - [NOTICE] simulation.solve(896): Capacity is now 4.939 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:07,988 - [NOTICE] simulation.solve(784): Cycle 33/1200 (6.670 s elapsed) --------------------
# 2021-08-20 16:51:07,988 - [NOTICE] simulation.solve(818): Cycle 33/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:08,025 - [NOTICE] simulation.solve(818): Cycle 33/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:08,064 - [NOTICE] simulation.solve(818): Cycle 33/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:08,114 - [NOTICE] simulation.solve(818): Cycle 33/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:08,173 - [NOTICE] simulation.solve(896): Capacity is now 4.938 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:08,174 - [NOTICE] simulation.solve(784): Cycle 34/1200 (6.856 s elapsed) --------------------
# 2021-08-20 16:51:08,174 - [NOTICE] simulation.solve(818): Cycle 34/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:08,216 - [NOTICE] simulation.solve(818): Cycle 34/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:08,245 - [NOTICE] simulation.solve(818): Cycle 34/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:08,281 - [NOTICE] simulation.solve(818): Cycle 34/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:08,342 - [NOTICE] simulation.solve(896): Capacity is now 4.937 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:08,343 - [NOTICE] simulation.solve(784): Cycle 35/1200 (7.026 s elapsed) --------------------
# 2021-08-20 16:51:08,344 - [NOTICE] simulation.solve(818): Cycle 35/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:08,409 - [NOTICE] simulation.solve(818): Cycle 35/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:08,472 - [NOTICE] simulation.solve(818): Cycle 35/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:08,526 - [NOTICE] simulation.solve(818): Cycle 35/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:08,587 - [NOTICE] simulation.solve(896): Capacity is now 4.936 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:08,589 - [NOTICE] simulation.solve(784): Cycle 36/1200 (7.271 s elapsed) --------------------
# 2021-08-20 16:51:08,589 - [NOTICE] simulation.solve(818): Cycle 36/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:08,636 - [NOTICE] simulation.solve(818): Cycle 36/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:08,668 - [NOTICE] simulation.solve(818): Cycle 36/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:08,714 - [NOTICE] simulation.solve(818): Cycle 36/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:08,778 - [NOTICE] simulation.solve(896): Capacity is now 4.935 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:08,778 - [NOTICE] simulation.solve(784): Cycle 37/1200 (7.460 s elapsed) --------------------
# 2021-08-20 16:51:08,779 - [NOTICE] simulation.solve(818): Cycle 37/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:08,837 - [NOTICE] simulation.solve(818): Cycle 37/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:08,877 - [NOTICE] simulation.solve(818): Cycle 37/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:08,917 - [NOTICE] simulation.solve(818): Cycle 37/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:08,970 - [NOTICE] simulation.solve(896): Capacity is now 4.934 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:08,971 - [NOTICE] simulation.solve(784): Cycle 38/1200 (7.653 s elapsed) --------------------
# 2021-08-20 16:51:08,971 - [NOTICE] simulation.solve(818): Cycle 38/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,010 - [NOTICE] simulation.solve(818): Cycle 38/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,036 - [NOTICE] simulation.solve(818): Cycle 38/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,073 - [NOTICE] simulation.solve(818): Cycle 38/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:09,125 - [NOTICE] simulation.solve(896): Capacity is now 4.933 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:09,125 - [NOTICE] simulation.solve(784): Cycle 39/1200 (7.808 s elapsed) --------------------
# 2021-08-20 16:51:09,126 - [NOTICE] simulation.solve(818): Cycle 39/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,166 - [NOTICE] simulation.solve(818): Cycle 39/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,193 - [NOTICE] simulation.solve(818): Cycle 39/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,227 - [NOTICE] simulation.solve(818): Cycle 39/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:09,274 - [NOTICE] simulation.solve(896): Capacity is now 4.932 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:09,274 - [NOTICE] simulation.solve(784): Cycle 40/1200 (7.956 s elapsed) --------------------
# 2021-08-20 16:51:09,274 - [NOTICE] simulation.solve(818): Cycle 40/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,315 - [NOTICE] simulation.solve(818): Cycle 40/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,342 - [NOTICE] simulation.solve(818): Cycle 40/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,379 - [NOTICE] simulation.solve(818): Cycle 40/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:09,428 - [NOTICE] simulation.solve(896): Capacity is now 4.931 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:09,429 - [NOTICE] simulation.solve(784): Cycle 41/1200 (8.111 s elapsed) --------------------
# 2021-08-20 16:51:09,430 - [NOTICE] simulation.solve(818): Cycle 41/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,468 - [NOTICE] simulation.solve(818): Cycle 41/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,494 - [NOTICE] simulation.solve(818): Cycle 41/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,530 - [NOTICE] simulation.solve(818): Cycle 41/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:09,579 - [NOTICE] simulation.solve(896): Capacity is now 4.930 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:09,580 - [NOTICE] simulation.solve(784): Cycle 42/1200 (8.262 s elapsed) --------------------
# 2021-08-20 16:51:09,580 - [NOTICE] simulation.solve(818): Cycle 42/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,618 - [NOTICE] simulation.solve(818): Cycle 42/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,647 - [NOTICE] simulation.solve(818): Cycle 42/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,683 - [NOTICE] simulation.solve(818): Cycle 42/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:09,734 - [NOTICE] simulation.solve(896): Capacity is now 4.929 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:09,735 - [NOTICE] simulation.solve(784): Cycle 43/1200 (8.417 s elapsed) --------------------
# 2021-08-20 16:51:09,735 - [NOTICE] simulation.solve(818): Cycle 43/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,775 - [NOTICE] simulation.solve(818): Cycle 43/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,802 - [NOTICE] simulation.solve(818): Cycle 43/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,838 - [NOTICE] simulation.solve(818): Cycle 43/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:09,887 - [NOTICE] simulation.solve(896): Capacity is now 4.928 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:09,887 - [NOTICE] simulation.solve(784): Cycle 44/1200 (8.569 s elapsed) --------------------
# 2021-08-20 16:51:09,888 - [NOTICE] simulation.solve(818): Cycle 44/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:09,927 - [NOTICE] simulation.solve(818): Cycle 44/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:09,954 - [NOTICE] simulation.solve(818): Cycle 44/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:09,991 - [NOTICE] simulation.solve(818): Cycle 44/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:10,042 - [NOTICE] simulation.solve(896): Capacity is now 4.927 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:10,043 - [NOTICE] simulation.solve(784): Cycle 45/1200 (8.725 s elapsed) --------------------
# 2021-08-20 16:51:10,043 - [NOTICE] simulation.solve(818): Cycle 45/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:10,084 - [NOTICE] simulation.solve(818): Cycle 45/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:10,110 - [NOTICE] simulation.solve(818): Cycle 45/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:10,147 - [NOTICE] simulation.solve(818): Cycle 45/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:10,197 - [NOTICE] simulation.solve(896): Capacity is now 4.926 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:10,198 - [NOTICE] simulation.solve(784): Cycle 46/1200 (8.880 s elapsed) --------------------
# 2021-08-20 16:51:10,199 - [NOTICE] simulation.solve(818): Cycle 46/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:10,237 - [NOTICE] simulation.solve(818): Cycle 46/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:10,263 - [NOTICE] simulation.solve(818): Cycle 46/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:10,300 - [NOTICE] simulation.solve(818): Cycle 46/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:10,350 - [NOTICE] simulation.solve(896): Capacity is now 4.925 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:10,351 - [NOTICE] simulation.solve(784): Cycle 47/1200 (9.033 s elapsed) --------------------
# 2021-08-20 16:51:10,352 - [NOTICE] simulation.solve(818): Cycle 47/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:10,393 - [NOTICE] simulation.solve(818): Cycle 47/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:10,422 - [NOTICE] simulation.solve(818): Cycle 47/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:10,459 - [NOTICE] simulation.solve(818): Cycle 47/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:10,509 - [NOTICE] simulation.solve(896): Capacity is now 4.924 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:10,510 - [NOTICE] simulation.solve(784): Cycle 48/1200 (9.192 s elapsed) --------------------
# 2021-08-20 16:51:10,510 - [NOTICE] simulation.solve(818): Cycle 48/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:10,552 - [NOTICE] simulation.solve(818): Cycle 48/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:10,578 - [NOTICE] simulation.solve(818): Cycle 48/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:10,615 - [NOTICE] simulation.solve(818): Cycle 48/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:10,670 - [NOTICE] simulation.solve(896): Capacity is now 4.923 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:10,671 - [NOTICE] simulation.solve(784): Cycle 49/1200 (9.353 s elapsed) --------------------
# 2021-08-20 16:51:10,671 - [NOTICE] simulation.solve(818): Cycle 49/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:10,710 - [NOTICE] simulation.solve(818): Cycle 49/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:10,738 - [NOTICE] simulation.solve(818): Cycle 49/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:10,776 - [NOTICE] simulation.solve(818): Cycle 49/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:10,837 - [NOTICE] simulation.solve(896): Capacity is now 4.922 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:10,838 - [NOTICE] simulation.solve(784): Cycle 50/1200 (9.520 s elapsed) --------------------
# 2021-08-20 16:51:10,838 - [NOTICE] simulation.solve(818): Cycle 50/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:10,905 - [NOTICE] simulation.solve(818): Cycle 50/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:10,941 - [NOTICE] simulation.solve(818): Cycle 50/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:10,985 - [NOTICE] simulation.solve(818): Cycle 50/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:11,047 - [NOTICE] simulation.solve(896): Capacity is now 4.921 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:11,049 - [NOTICE] simulation.solve(784): Cycle 51/1200 (9.731 s elapsed) --------------------
# 2021-08-20 16:51:11,050 - [NOTICE] simulation.solve(818): Cycle 51/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:11,092 - [NOTICE] simulation.solve(818): Cycle 51/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:11,121 - [NOTICE] simulation.solve(818): Cycle 51/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:11,160 - [NOTICE] simulation.solve(818): Cycle 51/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:11,215 - [NOTICE] simulation.solve(896): Capacity is now 4.920 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:11,216 - [NOTICE] simulation.solve(784): Cycle 52/1200 (9.898 s elapsed) --------------------
# 2021-08-20 16:51:11,216 - [NOTICE] simulation.solve(818): Cycle 52/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:11,258 - [NOTICE] simulation.solve(818): Cycle 52/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:11,286 - [NOTICE] simulation.solve(818): Cycle 52/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:11,323 - [NOTICE] simulation.solve(818): Cycle 52/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:11,374 - [NOTICE] simulation.solve(896): Capacity is now 4.919 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:11,374 - [NOTICE] simulation.solve(784): Cycle 53/1200 (10.057 s elapsed) --------------------
# 2021-08-20 16:51:11,375 - [NOTICE] simulation.solve(818): Cycle 53/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:11,413 - [NOTICE] simulation.solve(818): Cycle 53/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:11,442 - [NOTICE] simulation.solve(818): Cycle 53/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:11,480 - [NOTICE] simulation.solve(818): Cycle 53/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:11,532 - [NOTICE] simulation.solve(896): Capacity is now 4.918 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:11,532 - [NOTICE] simulation.solve(784): Cycle 54/1200 (10.214 s elapsed) --------------------
# 2021-08-20 16:51:11,532 - [NOTICE] simulation.solve(818): Cycle 54/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:11,570 - [NOTICE] simulation.solve(818): Cycle 54/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:11,598 - [NOTICE] simulation.solve(818): Cycle 54/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:11,634 - [NOTICE] simulation.solve(818): Cycle 54/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:11,687 - [NOTICE] simulation.solve(896): Capacity is now 4.918 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:11,688 - [NOTICE] simulation.solve(784): Cycle 55/1200 (10.370 s elapsed) --------------------
# 2021-08-20 16:51:11,688 - [NOTICE] simulation.solve(818): Cycle 55/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:11,727 - [NOTICE] simulation.solve(818): Cycle 55/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:11,755 - [NOTICE] simulation.solve(818): Cycle 55/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:11,790 - [NOTICE] simulation.solve(818): Cycle 55/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:11,839 - [NOTICE] simulation.solve(896): Capacity is now 4.917 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:11,840 - [NOTICE] simulation.solve(784): Cycle 56/1200 (10.522 s elapsed) --------------------
# 2021-08-20 16:51:11,840 - [NOTICE] simulation.solve(818): Cycle 56/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:11,887 - [NOTICE] simulation.solve(818): Cycle 56/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:11,918 - [NOTICE] simulation.solve(818): Cycle 56/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:11,963 - [NOTICE] simulation.solve(818): Cycle 56/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,021 - [NOTICE] simulation.solve(896): Capacity is now 4.916 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,022 - [NOTICE] simulation.solve(784): Cycle 57/1200 (10.704 s elapsed) --------------------
# 2021-08-20 16:51:12,023 - [NOTICE] simulation.solve(818): Cycle 57/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:12,060 - [NOTICE] simulation.solve(818): Cycle 57/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:12,086 - [NOTICE] simulation.solve(818): Cycle 57/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:12,121 - [NOTICE] simulation.solve(818): Cycle 57/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,171 - [NOTICE] simulation.solve(896): Capacity is now 4.915 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,172 - [NOTICE] simulation.solve(784): Cycle 58/1200 (10.854 s elapsed) --------------------
# 2021-08-20 16:51:12,172 - [NOTICE] simulation.solve(818): Cycle 58/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:12,208 - [NOTICE] simulation.solve(818): Cycle 58/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:12,235 - [NOTICE] simulation.solve(818): Cycle 58/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:12,270 - [NOTICE] simulation.solve(818): Cycle 58/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,319 - [NOTICE] simulation.solve(896): Capacity is now 4.914 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,320 - [NOTICE] simulation.solve(784): Cycle 59/1200 (11.002 s elapsed) --------------------
# 2021-08-20 16:51:12,323 - [NOTICE] simulation.solve(818): Cycle 59/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:12,364 - [NOTICE] simulation.solve(818): Cycle 59/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:12,397 - [NOTICE] simulation.solve(818): Cycle 59/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:12,439 - [NOTICE] simulation.solve(818): Cycle 59/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,491 - [NOTICE] simulation.solve(896): Capacity is now 4.913 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,492 - [NOTICE] simulation.solve(784): Cycle 60/1200 (11.174 s elapsed) --------------------
# 2021-08-20 16:51:12,492 - [NOTICE] simulation.solve(818): Cycle 60/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:12,535 - [NOTICE] simulation.solve(818): Cycle 60/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:12,567 - [NOTICE] simulation.solve(818): Cycle 60/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:12,606 - [NOTICE] simulation.solve(818): Cycle 60/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,664 - [NOTICE] simulation.solve(896): Capacity is now 4.912 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,665 - [NOTICE] simulation.solve(784): Cycle 61/1200 (11.347 s elapsed) --------------------
# 2021-08-20 16:51:12,665 - [NOTICE] simulation.solve(818): Cycle 61/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:12,705 - [NOTICE] simulation.solve(818): Cycle 61/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:12,738 - [NOTICE] simulation.solve(818): Cycle 61/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:12,778 - [NOTICE] simulation.solve(818): Cycle 61/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,831 - [NOTICE] simulation.solve(896): Capacity is now 4.911 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,831 - [NOTICE] simulation.solve(784): Cycle 62/1200 (11.514 s elapsed) --------------------
# 2021-08-20 16:51:12,832 - [NOTICE] simulation.solve(818): Cycle 62/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:12,875 - [NOTICE] simulation.solve(818): Cycle 62/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:12,903 - [NOTICE] simulation.solve(818): Cycle 62/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:12,938 - [NOTICE] simulation.solve(818): Cycle 62/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:12,990 - [NOTICE] simulation.solve(896): Capacity is now 4.910 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:12,990 - [NOTICE] simulation.solve(784): Cycle 63/1200 (11.672 s elapsed) --------------------
# 2021-08-20 16:51:12,990 - [NOTICE] simulation.solve(818): Cycle 63/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:13,028 - [NOTICE] simulation.solve(818): Cycle 63/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:13,057 - [NOTICE] simulation.solve(818): Cycle 63/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:13,095 - [NOTICE] simulation.solve(818): Cycle 63/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:13,148 - [NOTICE] simulation.solve(896): Capacity is now 4.909 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:13,149 - [NOTICE] simulation.solve(784): Cycle 64/1200 (11.831 s elapsed) --------------------
# 2021-08-20 16:51:13,149 - [NOTICE] simulation.solve(818): Cycle 64/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:13,191 - [NOTICE] simulation.solve(818): Cycle 64/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:13,224 - [NOTICE] simulation.solve(818): Cycle 64/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:13,265 - [NOTICE] simulation.solve(818): Cycle 64/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:13,323 - [NOTICE] simulation.solve(896): Capacity is now 4.908 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:13,323 - [NOTICE] simulation.solve(784): Cycle 65/1200 (12.005 s elapsed) --------------------
# 2021-08-20 16:51:13,324 - [NOTICE] simulation.solve(818): Cycle 65/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:13,366 - [NOTICE] simulation.solve(818): Cycle 65/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:13,396 - [NOTICE] simulation.solve(818): Cycle 65/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:13,437 - [NOTICE] simulation.solve(818): Cycle 65/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:13,492 - [NOTICE] simulation.solve(896): Capacity is now 4.907 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:13,494 - [NOTICE] simulation.solve(784): Cycle 66/1200 (12.176 s elapsed) --------------------
# 2021-08-20 16:51:13,494 - [NOTICE] simulation.solve(818): Cycle 66/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:13,538 - [NOTICE] simulation.solve(818): Cycle 66/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:13,568 - [NOTICE] simulation.solve(818): Cycle 66/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:13,604 - [NOTICE] simulation.solve(818): Cycle 66/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:13,657 - [NOTICE] simulation.solve(896): Capacity is now 4.906 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:13,657 - [NOTICE] simulation.solve(784): Cycle 67/1200 (12.339 s elapsed) --------------------
# 2021-08-20 16:51:13,658 - [NOTICE] simulation.solve(818): Cycle 67/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:13,698 - [NOTICE] simulation.solve(818): Cycle 67/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:13,727 - [NOTICE] simulation.solve(818): Cycle 67/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:13,763 - [NOTICE] simulation.solve(818): Cycle 67/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:13,810 - [NOTICE] simulation.solve(896): Capacity is now 4.905 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:13,810 - [NOTICE] simulation.solve(784): Cycle 68/1200 (12.492 s elapsed) --------------------
# 2021-08-20 16:51:13,811 - [NOTICE] simulation.solve(818): Cycle 68/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:13,849 - [NOTICE] simulation.solve(818): Cycle 68/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:13,874 - [NOTICE] simulation.solve(818): Cycle 68/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:13,911 - [NOTICE] simulation.solve(818): Cycle 68/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:13,963 - [NOTICE] simulation.solve(896): Capacity is now 4.904 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:13,963 - [NOTICE] simulation.solve(784): Cycle 69/1200 (12.645 s elapsed) --------------------
# 2021-08-20 16:51:13,963 - [NOTICE] simulation.solve(818): Cycle 69/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:14,000 - [NOTICE] simulation.solve(818): Cycle 69/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:14,026 - [NOTICE] simulation.solve(818): Cycle 69/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:14,063 - [NOTICE] simulation.solve(818): Cycle 69/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:14,116 - [NOTICE] simulation.solve(896): Capacity is now 4.903 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:14,117 - [NOTICE] simulation.solve(784): Cycle 70/1200 (12.799 s elapsed) --------------------
# 2021-08-20 16:51:14,117 - [NOTICE] simulation.solve(818): Cycle 70/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:14,158 - [NOTICE] simulation.solve(818): Cycle 70/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:14,186 - [NOTICE] simulation.solve(818): Cycle 70/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:14,225 - [NOTICE] simulation.solve(818): Cycle 70/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:14,272 - [NOTICE] simulation.solve(896): Capacity is now 4.902 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:14,273 - [NOTICE] simulation.solve(784): Cycle 71/1200 (12.955 s elapsed) --------------------
# 2021-08-20 16:51:14,273 - [NOTICE] simulation.solve(818): Cycle 71/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:14,310 - [NOTICE] simulation.solve(818): Cycle 71/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:14,342 - [NOTICE] simulation.solve(818): Cycle 71/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:14,384 - [NOTICE] simulation.solve(818): Cycle 71/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:14,439 - [NOTICE] simulation.solve(896): Capacity is now 4.901 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:14,439 - [NOTICE] simulation.solve(784): Cycle 72/1200 (13.121 s elapsed) --------------------
# 2021-08-20 16:51:14,439 - [NOTICE] simulation.solve(818): Cycle 72/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:14,482 - [NOTICE] simulation.solve(818): Cycle 72/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:14,509 - [NOTICE] simulation.solve(818): Cycle 72/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:51:14,566 - [NOTICE] simulation.solve(818): Cycle 72/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:51:14,632 - [NOTICE] simulation.solve(896): Capacity is now 4.900 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:51:14,632 - [NOTICE] simulation.solve(784): Cycle 73/1200 (13.314 s elapsed) --------------------
# 2021-08-20 16:51:14,633 - [NOTICE] simulation.solve(818): Cycle 73/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:51:14,679 - [NOTICE] simulation.solve(818): Cycle 73/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:51:14,709 - [NOTICE] simulation.solve(818): Cycle 73/1200, step 3/4: Charge at 1C until 4.2V
# ...
# 2021-08-20 16:54:03,729 - [NOTICE] simulation.solve(896): Capacity is now 3.057 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:03,729 - [NOTICE] simulation.solve(784): Cycle 1061/1200 (3 minutes, 2 seconds elapsed) --------------------
# 2021-08-20 16:54:03,730 - [NOTICE] simulation.solve(818): Cycle 1061/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:03,758 - [NOTICE] simulation.solve(818): Cycle 1061/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:03,820 - [NOTICE] simulation.solve(818): Cycle 1061/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:03,854 - [NOTICE] simulation.solve(818): Cycle 1061/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:03,914 - [NOTICE] simulation.solve(896): Capacity is now 3.054 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:03,914 - [NOTICE] simulation.solve(784): Cycle 1062/1200 (3 minutes, 3 seconds elapsed) --------------------
# 2021-08-20 16:54:03,915 - [NOTICE] simulation.solve(818): Cycle 1062/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:03,956 - [NOTICE] simulation.solve(818): Cycle 1062/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:03,983 - [NOTICE] simulation.solve(818): Cycle 1062/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,009 - [NOTICE] simulation.solve(818): Cycle 1062/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:04,068 - [NOTICE] simulation.solve(896): Capacity is now 3.051 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:04,069 - [NOTICE] simulation.solve(784): Cycle 1063/1200 (3 minutes, 3 seconds elapsed) --------------------
# 2021-08-20 16:54:04,069 - [NOTICE] simulation.solve(818): Cycle 1063/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:04,114 - [NOTICE] simulation.solve(818): Cycle 1063/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:04,138 - [NOTICE] simulation.solve(818): Cycle 1063/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,164 - [NOTICE] simulation.solve(818): Cycle 1063/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:04,238 - [NOTICE] simulation.solve(896): Capacity is now 3.047 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:04,238 - [NOTICE] simulation.solve(784): Cycle 1064/1200 (3 minutes, 3 seconds elapsed) --------------------
# 2021-08-20 16:54:04,239 - [NOTICE] simulation.solve(818): Cycle 1064/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:04,265 - [NOTICE] simulation.solve(818): Cycle 1064/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:04,290 - [NOTICE] simulation.solve(818): Cycle 1064/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,334 - [NOTICE] simulation.solve(818): Cycle 1064/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:04,406 - [NOTICE] simulation.solve(896): Capacity is now 3.044 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:04,406 - [NOTICE] simulation.solve(784): Cycle 1065/1200 (3 minutes, 3 seconds elapsed) --------------------
# 2021-08-20 16:54:04,407 - [NOTICE] simulation.solve(818): Cycle 1065/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:04,434 - [NOTICE] simulation.solve(818): Cycle 1065/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:04,459 - [NOTICE] simulation.solve(818): Cycle 1065/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,485 - [NOTICE] simulation.solve(818): Cycle 1065/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:04,557 - [NOTICE] simulation.solve(896): Capacity is now 3.040 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:04,557 - [NOTICE] simulation.solve(784): Cycle 1066/1200 (3 minutes, 3 seconds elapsed) --------------------
# 2021-08-20 16:54:04,557 - [NOTICE] simulation.solve(818): Cycle 1066/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:04,584 - [NOTICE] simulation.solve(818): Cycle 1066/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:04,609 - [NOTICE] simulation.solve(818): Cycle 1066/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,635 - [NOTICE] simulation.solve(818): Cycle 1066/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:04,692 - [NOTICE] simulation.solve(896): Capacity is now 3.037 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:04,692 - [NOTICE] simulation.solve(784): Cycle 1067/1200 (3 minutes, 3 seconds elapsed) --------------------
# 2021-08-20 16:54:04,692 - [NOTICE] simulation.solve(818): Cycle 1067/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:04,734 - [NOTICE] simulation.solve(818): Cycle 1067/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:04,758 - [NOTICE] simulation.solve(818): Cycle 1067/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,783 - [NOTICE] simulation.solve(818): Cycle 1067/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:04,855 - [NOTICE] simulation.solve(896): Capacity is now 3.034 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:04,856 - [NOTICE] simulation.solve(784): Cycle 1068/1200 (3 minutes, 4 seconds elapsed) --------------------
# 2021-08-20 16:54:04,856 - [NOTICE] simulation.solve(818): Cycle 1068/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:04,896 - [NOTICE] simulation.solve(818): Cycle 1068/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:04,921 - [NOTICE] simulation.solve(818): Cycle 1068/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:04,949 - [NOTICE] simulation.solve(818): Cycle 1068/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:05,037 - [NOTICE] simulation.solve(896): Capacity is now 3.030 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:05,037 - [NOTICE] simulation.solve(784): Cycle 1069/1200 (3 minutes, 4 seconds elapsed) --------------------
# 2021-08-20 16:54:05,038 - [NOTICE] simulation.solve(818): Cycle 1069/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:05,066 - [NOTICE] simulation.solve(818): Cycle 1069/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:05,092 - [NOTICE] simulation.solve(818): Cycle 1069/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:05,116 - [NOTICE] simulation.solve(818): Cycle 1069/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:05,192 - [NOTICE] simulation.solve(896): Capacity is now 3.027 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:05,192 - [NOTICE] simulation.solve(784): Cycle 1070/1200 (3 minutes, 4 seconds elapsed) --------------------
# 2021-08-20 16:54:05,193 - [NOTICE] simulation.solve(818): Cycle 1070/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:05,224 - [NOTICE] simulation.solve(818): Cycle 1070/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:05,254 - [NOTICE] simulation.solve(818): Cycle 1070/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:05,282 - [NOTICE] simulation.solve(818): Cycle 1070/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:05,362 - [NOTICE] simulation.solve(896): Capacity is now 3.023 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:05,362 - [NOTICE] simulation.solve(784): Cycle 1071/1200 (3 minutes, 4 seconds elapsed) --------------------
# 2021-08-20 16:54:05,362 - [NOTICE] simulation.solve(818): Cycle 1071/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:05,389 - [NOTICE] simulation.solve(818): Cycle 1071/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:05,415 - [NOTICE] simulation.solve(818): Cycle 1071/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:05,439 - [NOTICE] simulation.solve(818): Cycle 1071/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:05,504 - [NOTICE] simulation.solve(896): Capacity is now 3.020 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:05,504 - [NOTICE] simulation.solve(784): Cycle 1072/1200 (3 minutes, 4 seconds elapsed) --------------------
# 2021-08-20 16:54:05,505 - [NOTICE] simulation.solve(818): Cycle 1072/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:05,557 - [NOTICE] simulation.solve(818): Cycle 1072/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:05,589 - [NOTICE] simulation.solve(818): Cycle 1072/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:05,618 - [NOTICE] simulation.solve(818): Cycle 1072/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:05,694 - [NOTICE] simulation.solve(896): Capacity is now 3.016 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:05,694 - [NOTICE] simulation.solve(784): Cycle 1073/1200 (3 minutes, 4 seconds elapsed) --------------------
# 2021-08-20 16:54:05,695 - [NOTICE] simulation.solve(818): Cycle 1073/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:05,720 - [NOTICE] simulation.solve(818): Cycle 1073/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:05,745 - [NOTICE] simulation.solve(818): Cycle 1073/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:05,768 - [NOTICE] simulation.solve(818): Cycle 1073/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:05,841 - [NOTICE] simulation.solve(896): Capacity is now 3.013 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:05,841 - [NOTICE] simulation.solve(784): Cycle 1074/1200 (3 minutes, 5 seconds elapsed) --------------------
# 2021-08-20 16:54:05,841 - [NOTICE] simulation.solve(818): Cycle 1074/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:05,885 - [NOTICE] simulation.solve(818): Cycle 1074/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:05,910 - [NOTICE] simulation.solve(818): Cycle 1074/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:05,936 - [NOTICE] simulation.solve(818): Cycle 1074/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:06,013 - [NOTICE] simulation.solve(896): Capacity is now 3.010 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:06,014 - [NOTICE] simulation.solve(784): Cycle 1075/1200 (3 minutes, 5 seconds elapsed) --------------------
# 2021-08-20 16:54:06,014 - [NOTICE] simulation.solve(818): Cycle 1075/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:06,047 - [NOTICE] simulation.solve(818): Cycle 1075/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:06,082 - [NOTICE] simulation.solve(818): Cycle 1075/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:06,108 - [NOTICE] simulation.solve(818): Cycle 1075/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:06,167 - [NOTICE] simulation.solve(896): Capacity is now 3.006 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:06,168 - [NOTICE] simulation.solve(784): Cycle 1076/1200 (3 minutes, 5 seconds elapsed) --------------------
# 2021-08-20 16:54:06,168 - [NOTICE] simulation.solve(818): Cycle 1076/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:06,211 - [NOTICE] simulation.solve(818): Cycle 1076/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:06,238 - [NOTICE] simulation.solve(818): Cycle 1076/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:06,262 - [NOTICE] simulation.solve(818): Cycle 1076/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:06,323 - [NOTICE] simulation.solve(896): Capacity is now 3.003 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:06,323 - [NOTICE] simulation.solve(784): Cycle 1077/1200 (3 minutes, 5 seconds elapsed) --------------------
# 2021-08-20 16:54:06,323 - [NOTICE] simulation.solve(818): Cycle 1077/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:06,367 - [NOTICE] simulation.solve(818): Cycle 1077/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:06,413 - [NOTICE] simulation.solve(818): Cycle 1077/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:06,437 - [NOTICE] simulation.solve(818): Cycle 1077/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:06,507 - [NOTICE] simulation.solve(896): Capacity is now 2.999 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:06,508 - [NOTICE] simulation.solve(784): Cycle 1078/1200 (3 minutes, 5 seconds elapsed) --------------------
# 2021-08-20 16:54:06,508 - [NOTICE] simulation.solve(818): Cycle 1078/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:06,535 - [NOTICE] simulation.solve(818): Cycle 1078/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:06,564 - [NOTICE] simulation.solve(818): Cycle 1078/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:06,592 - [NOTICE] simulation.solve(818): Cycle 1078/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:06,688 - [NOTICE] simulation.solve(896): Capacity is now 2.996 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:06,688 - [NOTICE] simulation.solve(784): Cycle 1079/1200 (3 minutes, 5 seconds elapsed) --------------------
# 2021-08-20 16:54:06,689 - [NOTICE] simulation.solve(818): Cycle 1079/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:06,721 - [NOTICE] simulation.solve(818): Cycle 1079/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:06,750 - [NOTICE] simulation.solve(818): Cycle 1079/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:06,776 - [NOTICE] simulation.solve(818): Cycle 1079/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:06,866 - [NOTICE] simulation.solve(896): Capacity is now 2.992 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:06,868 - [NOTICE] simulation.solve(784): Cycle 1080/1200 (3 minutes, 6 seconds elapsed) --------------------
# 2021-08-20 16:54:06,868 - [NOTICE] simulation.solve(818): Cycle 1080/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:06,901 - [NOTICE] simulation.solve(818): Cycle 1080/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:06,931 - [NOTICE] simulation.solve(818): Cycle 1080/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:06,976 - [NOTICE] simulation.solve(818): Cycle 1080/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:07,058 - [NOTICE] simulation.solve(896): Capacity is now 2.989 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:07,059 - [NOTICE] simulation.solve(784): Cycle 1081/1200 (3 minutes, 6 seconds elapsed) --------------------
# 2021-08-20 16:54:07,060 - [NOTICE] simulation.solve(818): Cycle 1081/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:07,091 - [NOTICE] simulation.solve(818): Cycle 1081/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:07,129 - [NOTICE] simulation.solve(818): Cycle 1081/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:07,159 - [NOTICE] simulation.solve(818): Cycle 1081/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:07,235 - [NOTICE] simulation.solve(896): Capacity is now 2.985 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:07,235 - [NOTICE] simulation.solve(784): Cycle 1082/1200 (3 minutes, 6 seconds elapsed) --------------------
# 2021-08-20 16:54:07,236 - [NOTICE] simulation.solve(818): Cycle 1082/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:07,270 - [NOTICE] simulation.solve(818): Cycle 1082/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:07,301 - [NOTICE] simulation.solve(818): Cycle 1082/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:07,328 - [NOTICE] simulation.solve(818): Cycle 1082/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:07,405 - [NOTICE] simulation.solve(896): Capacity is now 2.982 Ah (originally 4.968 Ah, will stop at 2.981 Ah)
# 2021-08-20 16:54:07,405 - [NOTICE] simulation.solve(784): Cycle 1083/1200 (3 minutes, 6 seconds elapsed) --------------------
# 2021-08-20 16:54:07,405 - [NOTICE] simulation.solve(818): Cycle 1083/1200, step 1/4: Discharge at 1C until 3V
# 2021-08-20 16:54:07,432 - [NOTICE] simulation.solve(818): Cycle 1083/1200, step 2/4: Rest for 1 hour
# 2021-08-20 16:54:07,457 - [NOTICE] simulation.solve(818): Cycle 1083/1200, step 3/4: Charge at 1C until 4.2V
# 2021-08-20 16:54:07,482 - [NOTICE] simulation.solve(818): Cycle 1083/1200, step 4/4: Hold at 4.2V until C/50
# 2021-08-20 16:54:07,558 - [NOTICE] simulation.solve(902): Stopping experiment since capacity (2.978 Ah) is below stopping capacity (2.981 Ah).
# 2021-08-20 16:54:07,589 - [NOTICE] simulation.solve(913): Finish experiment simulation, took 3 minutes, 6 seconds

# %% [markdown]
# ## Export results to pickle file

# %%
sumvar = sol_long_knee.summary_variables

import pickle
filehandler = open("saturation.pkl","wb")
pickle.dump(sumvar, filehandler)
